# %% [raw]
# ---
# categories:
# - Collaboration
# comments: true
# courses:
#   csp:
#     week: 3
# description: This page is for comments on my repository.
# layout: post
# permalink: /CommentPage/csp/
# title: Comment Page
# type: collab
# ---
