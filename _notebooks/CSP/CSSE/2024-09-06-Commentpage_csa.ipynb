# %% [raw]
# ---
# categories:
# - Collaboration
# comments: true
# courses:
#   csa:
#     week: 2
# description: This page is for comments on my repository.
# layout: post
# permalink: /CommentPage/csa/
# title: Comment Page
# type: collab
# ---
