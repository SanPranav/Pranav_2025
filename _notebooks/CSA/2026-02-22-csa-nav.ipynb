# %% [markdown]
# ---
# layout: page
# title: CSA Navigation
# description: Auto-updating CSA navbar
# permalink: /csa/
# ---

# %% [markdown]
# This page auto-updates by scanning CSA pages and grouping them by title.
#
# ## Blogs
# {% assign csa_pages = site.pages | where_exp: "p", "p.path contains '_notebooks/CSA/'" | sort: "title" %}
# {% assign csa_posts = site.posts | where_exp: "p", "p.path contains '_posts/CSA/'" | sort: "title" %}
#
# {% assign blog_count = 0 %}
# {% for p in csa_pages %}
#   {% assign t = p.title | downcase %}
#   {% if t contains "blog" %}
# - [{{ p.title }}]({{ site.baseurl }}{{ p.url }})
#     {% assign blog_count = blog_count | plus: 1 %}
#   {% endif %}
# {% endfor %}
# {% for p in csa_posts %}
#   {% assign t = p.title | downcase %}
#   {% if t contains "blog" %}
# - [{{ p.title }}]({{ site.baseurl }}{{ p.url }})
#     {% assign blog_count = blog_count | plus: 1 %}
#   {% endif %}
# {% endfor %}
# {% if blog_count == 0 %}
# No CSA blogs yet.
# {% endif %}
#
# ## Homeworks
# {% assign hw_count = 0 %}
# {% for p in csa_pages %}
#   {% assign t = p.title | downcase %}
#   {% if t contains "hw" or t contains "homework" %}
# - [{{ p.title }}]({{ site.baseurl }}{{ p.url }})
#     {% assign hw_count = hw_count | plus: 1 %}
#   {% endif %}
# {% endfor %}
# {% for p in csa_posts %}
#   {% assign t = p.title | downcase %}
#   {% if t contains "hw" or t contains "homework" %}
# - [{{ p.title }}]({{ site.baseurl }}{{ p.url }})
#     {% assign hw_count = hw_count | plus: 1 %}
#   {% endif %}
# {% endfor %}
# {% if hw_count == 0 %}
# No CSA homeworks yet.
# {% endif %}
#
# ## Other
# {% assign other_count = 0 %}
# {% for p in csa_pages %}
#   {% assign t = p.title | downcase %}
#   {% if t contains "blog" or t contains "hw" or t contains "homework" %}
#   {% else %}
# - [{{ p.title }}]({{ site.baseurl }}{{ p.url }})
#     {% assign other_count = other_count | plus: 1 %}
#   {% endif %}
# {% endfor %}
# {% for p in csa_posts %}
#   {% assign t = p.title | downcase %}
#   {% if t contains "blog" or t contains "hw" or t contains "homework" %}
#   {% else %}
# - [{{ p.title }}]({{ site.baseurl }}{{ p.url }})
#     {% assign other_count = other_count | plus: 1 %}
#   {% endif %}
# {% endfor %}
# {% if other_count == 0 %}
# No other CSA pages yet.
# {% endif %}
