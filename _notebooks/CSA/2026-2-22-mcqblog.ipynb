# %% [markdown]
# ---
# layout: post
# title: MCQ Blog Tri 2
# description: How I improved from 22 to 36
# type: collab
# comments: true
# permalink: /csa/blogs/mcqblog1
# ---

# %% [markdown]
# # MCQ Improvement Blog
#
# ## Overview
# I retook the practice MCQ and improved my score from **22/42** to **36/42**. This post breaks down what changed, where I improved, and which questions I still missed so I can target them next.
#
# ## Evidence (Screenshots)
# Below are the screenshots showing the score change and the questions I missed. I will keep these here as proof of growth.
#
# ![Practice exam scores comparison](images/mcq_scores_22_to_36.png)
#
# ![Incorrect Q41 - execution counts](images/mcq_q41_execution_counts.png)
#
# ![Incorrect Q40 - array after passes](images/mcq_q40_two_passes.png)
#
# ![Incorrect Q38 - maxPages](images/mcq_q38_maxpages.png)
#
# ![Incorrect Q27 - mystery array traversal](images/mcq_q27_mystery_array.png)
#
# ![Incorrect Q21 - system reliability](images/mcq_q21_reliability.png)
#
# ![Incorrect Q10 - value after operations](images/mcq_q10_value_after_ops.png)
#
# ## Score Growth
# - Baseline: **22/42**
# - Latest: **36/42**
# - Net change: **+14** (about **+33%** of the total exam)

# %% [markdown]
# ```mermaid
# flowchart LR
#     A[Practice Exam 1: 22/42] --> B[Practice Exam 2: 36/42]
# ```

# %% [markdown]
# ## Improvements by Category
# The questions I missed cluster around tracing code behavior, loop execution counts, and selection sort mechanics. I will keep drilling these topics.

# %% [markdown]
# ```mermaid
# xychart-beta
#     title "Incorrect Questions by Topic Code"
#     x-axis ["2.12", "4.15", "4.10", "4.4", "3.2", "1.3"]
#     y-axis "Count" 0 --> 1
#     bar [1, 1, 1, 1, 1, 1]
# ```

# %% [markdown]
# ## Incorrect Questions (Leave Room for Corrections)
# I left space to add my fixes and explanations for each missed question.
#
# | Question | Topic | Skills | Time Spent | Result | Fix / Notes |
# | --- | --- | --- | --- | --- | --- |
# | Q41 | 2.12 | 4.15 | 00:22 | 0/1 |  |
# | Q40 | 4.15 | 00:54 | 0/1 |  |
# | Q38 | 4.10 | 00:23 | 0/1 |  |
# | Q27 | 4.4 | 01:44 | 0/1 |  |
# | Q21 | 3.2 | 00:18 | 0/1 |  |
# | Q10 | 1.3 | 01:06 | 0/1 |  |
#
# ## Reflection
# I improved by reviewing common AP CSA patterns like tracing loops, integer math, and selection sort steps. The remaining misses are mostly short-trace questions where I rushed. My next goal is to slow down on these and verify each step.
#
#
# ## Next Steps
# - Redo each missed question and fill in the Fix / Notes column.
# - Drill selection sort traces and loop iteration counts.
# - Re-run a timed practice and compare results again.
