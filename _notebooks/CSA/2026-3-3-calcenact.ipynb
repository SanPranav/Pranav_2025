// %% [markdown]
// ---
// layout: post
// title: Calculator Renactment
// description:
// type: collab
// comments: true
// permalink: /csa/hw/calcenact
// ---

// %% [markdown]
// ## Calculator Enactment - Live Performance Script
//
// Your team of 15 will act out how a calculator actually works using Reverse Polish Notation. This isn't a presentation - you're physically becoming the algorithm.

// %% [markdown]
// ## What You're Doing
//
// You're going to physically act out how a calculator works. Not a simple calculator - the RPN (Reverse Polish Notation) algorithm that computers actually use.
//
// **Why this matters:** You'll see three data structures (HashMap, ArrayList, Stack) working together to solve one problem. This is how real code works - multiple structures collaborating.
//
// **What to expect:** About 5-7 minutes of performance. You'll transform "5 + 3 * 2" into an answer by being the algorithm. Some of you will be numbers, some will be operators, some will manage the data structures.
//
// **Goal:** Make the class understand why precedence matters and how stacks make it work.

// %% [markdown]
// ## Team Setup (15 People)
//
// **Director (1)** - Narrates to the class, explains what's happening
// **Tokenizer (1)** - Calls out each character, sends tokens to queue
// **RPN Boss (1)** - Controls the operator stack, makes precedence decisions
// **Calculator (1)** - Runs the final calculations
// **Data Structure Explainers (2)** - Explain HashMap, ArrayList, Stack as they're used
// **Tokens (9)** - You ARE the numbers and operators (use phones to show your value)
//
// **Props:** Phones with big numbers, tape on floor for stations, chairs for "stacks"

// %% [markdown]
// ## Pick Your Expression
//
// **Easy:** `5 + 3 * 2` = 11 (needs 5 tokens)
// **Medium:** `(10 + 5) * 2 - 3` = 27 (needs 7 tokens)
// **Hard:** `√(3^2 + 4^2)` = 5 (needs 6 tokens)
//
// With 9 token actors, you can do all three or run the medium one twice with different people.

// %% [markdown]
// ## SCRIPT: Easy Version `5 + 3 * 2`
//
// ### Phase 1: Tokenization
//
// **Director:** "Alright class, we're calculating 5 + 3 * 2. First step - break it down into tokens. Think of it like breaking a pizza into slices. Except nobody eats the slices here. Sadly."
//
// **Data Explainer 1:** "We're using an ArrayList here - it keeps things in order. Think of it like a line at lunch. Except way more organized and nobody's cutting in."
//
// **Tokenizer:** "First up, 5!" *[Token-5 walks forward with unnecessary confidence, phone shows 5. Waves to class]*
// **Tokenizer:** "Plus sign!" *[Token-+ struts forward like it's the star of the show, phone shows +]*
// **Tokenizer:** "The number 3!" *[Token-3 walks forward, trips slightly, recovers with a thumbs up]*
// **Tokenizer:** "Multiplication—THE MAIN CHARACTER!" *[Token-* dramatically throws hands up, music cue if possible]*
// **Tokenizer:** "And finally, 2!" *[Token-2 walks lazily, clearly hasn't been paid]*
//
// **Director:** "Tokenization done. We've got our ArrayList: [5, +, 3, *, 2]. It's beautiful. *chef's kiss* It's tragic that we're about to destroy this order."
//
// ---
//
// ### Phase 2: Converting to RPN
//
// **Director:** "Now for the ACTUALLY tricky part—reordering this to respect math rules. Multiplication happens before addition, right? SPOILER: The plus sign is about to get betrayed."
//
// **Data Explainer 2:** "We're using a Stack now—last in, first out. Like a stack of plates. Or a stack of cold pizza boxes. Could be either."
//
// **RPN Boss:** "Okay token-5, you're a number. Numbers go straight through. Move to the RPN line with confidence!"
// *[Token-5 walks to RPN area, shyly waves]*
//
// **RPN Boss:** "Token-+, you're an operator. Stack's empty, so hop on the stack."
// *[Token-+ jumps onto a chair, suddenly feels important]*
//
// **RPN Boss:** "Token-3, you're a number. Go to RPN output! Live your best life!"
// *[Token-3 moves to RPN area, stands behind Token-5, whispers in its ear]*
//
// **RPN Boss:** "Token-*, now THIS is interesting. You have precedence 3. Plus has precedence 4. Lower number wins—you're LITERALLY more important! Get on the stack above plus."
// *[Token-* climbs dramatically onto the chair above Token-+, Token-+ looks betrayed]*
//
// **Director:** "See that? BETRAYAL. The stack is holding operators based on priority. That's how we respect order of operations. Plus sign, your alliance is broken."
//
// **Token-+:** *[dramatically from the chair]* "But I thought we were team!"
//
// **RPN Boss:** "Token-2, you're a number. RPN output!"
// *[Token-2 shuffles to RPN area, still unbothered]*
//
// **RPN Boss:** "No more tokens. Time to empty the stack. Top first—that's multiply! GET DOWN FROM THERE."
// *[Token-* jumps off, slides into RPN area dramatically]*
//
// **RPN Boss:** "Now plus! Stop pouting and come down."
// *[Token-+ climbs down sadly, stands at end of RPN line]*
//
// **Director:** "Look at that redemption arc. We went from [5, +, 3, *, 2] to [5, 3, 2, *, +]. The ORDER CHANGED. Your favorite operator is now LAST."
//
// ---
//
// ### Phase 3: Calculate It
//
// **Director:** "Final step—actually do the math. No more drama. Well, I can't promise that."
//
// **Calculator:** "Token-5, you're a number. Get on the calculation stack."
// *[Token-5 sits in a chair]*
//
// **Calculator:** "Token-3, number. On the stack!"
// *[Token-3 sits in front of Token-5]*
//
// **Calculator:** "Token-2, number. On the stack!"
// *[Token-2 sits in front of Token-3]*
//
// **Calculator:** "Token-*, you're an operator! That means pop two numbers and calculate. POP!"
// *[Token-2 jumps up dramatically, stands between operator and numbers]*
//
// **Calculator:** "Pop again!"
// *[Token-3 jumps up, confused]*
//
// **Calculator:** "What's 3 times 2?"
// **Token-3 and Token-2:** "SIX!" *[both scream this with unnecessary enthusiasm]*
//
// **Calculator:** "Token-2, update your phone to 6. Token-3, you're GONE. Sit down."
// *[Token-3 sits defeated, Token-2 changes phone to 6, sits back down]*
//
// **Director:** "THIS IS THE MAGIC. Two tokens became one. Budget cuts. The algorithm is EFFICIENT."
//
// **Calculator:** "Token-+, you're an operator! Pop!"
// *[Token-2/6 jumps up excitedly]*
//
// **Calculator:** "Pop!"
// *[Token-5 jumps up]*
//
// **Calculator:** "What's 5 plus 6?"
// **Token-5 and Token-2/6:** "ELEVEN!" *[both do a little dance]*
//
// **Calculator:** "Token-2, make it 11. Token-5, you can sit now."
// *[Token-5 sits down peacefully, Token-2 shows 11]*
//
// **Director:** "And THERE'S our answer—11! That is EXACTLY what 5 + 3 * 2 should be. The algorithm wins. Math wins. Everyone goes home. Except Token-3 and Token-5. They lost."
//
// **Data Explainer 1:** "We used three data structures: ArrayList for keeping order, Stack for handling the drama and betrayal, and HashMap to look up operator rules. The story of two numbers that lost their independence."

// %% [markdown]
// ## SCRIPT: Medium Version `(10 + 5) * 2 - 3`
//
// **Director:** "Alright, round two. This time we have PARENTHESES: (10 + 5) * 2 - 3. Parentheses are basically saying 'LISTEN TO ME FIRST OR SO HELP ME...' They're the BOSSY part of math."
//
// **Data Explainer 2:** "Parentheses use the Stack to FORCE things to calculate in a specific order. They're like saying 'hey, do this FIRST or the algorithm breaks.' It's coercive math."
//
// ### Tokenize It
//
// **Tokenizer:** "Open paren!" *[Token-( walks forward with authority]*
// **Tokenizer:** "10!" *[Token-10 walks forward, feels large and in charge]*
// **Tokenizer:** "Plus!" *[Token-+ walks forward, still holding a grudge from the last round]*
// **Tokenizer:** "5!" *[Token-5 walks forward, Team 10]*
// **Tokenizer:** "Close paren!" *[Token-) walks forward, nervous about responsibility]*
// **Tokenizer:** "Times!" *[Token-* walks forward, ready for redemption]*
// **Tokenizer:** "2!" *[Token-2 walks forward]*
// **Tokenizer:** "Minus!" *[Token-- walks forward with a swagger, NEW CHARACTER, no reputation]*
// **Tokenizer:** "3!" *[Token-3 walks forward, the final victim]*
//
// ---
//
// ### RPN Time
//
// **RPN Boss:** "Open paren, get on the operator stack." *[( sits on stack like a placeholder]*
//
// **RPN Boss:** "10, you're a number. Straight to RPN!" *[10 moves, confident]*
//
// **RPN Boss:** "Plus, onto the stack above that paren." *[+ sits down, now it's cooking with gas]*
//
// **RPN Boss:** "5, number, go!" *[5 moves to join 10]*
//
// **RPN Boss:** "Close paren—OK THIS IS THE IMPORTANT PART! THIS IS WHERE THE MAGIC HAPPENS!"
//
// **Director:** "Everyone—when you see a close paren, WHAT HAPPENS? Someone answer! ANYONE?"
//
// **All:** *[awkward silence]*
//
// **RPN Boss:** "We pop EVERYTHING back to the matching open paren!" *[+ gets violently ejected to RPN]* "And then the paren DISAPPEARS like it was never here!"
// *[( vanishes]*
//
// **Director:** "BAM! That plus got FORCED into the RPN early. THAT'S the whole trick right there. The parentheses are GONE now but they did their job. They were the villain THAT CREATED RESULTS."
//
// **RPN Boss:** "Times, you're up. Stack's empty so get on." *[* sits, feeling confident again]*
//
// **RPN Boss:** "2, to RPN." *[2 moves]*
//
// **RPN Boss:** "Minus—but wait, multiply's got better precedence." *[* launches to RPN]* "Now minus, you're on the stack."
// *[- sits down, feels like part of the OG operator squad]*
//
// **RPN Boss:** "3, RPN." *[3 moves]*
//
// **RPN Boss:** "Clear the stack—minus, move!" *[- flies to RPN]*
//
// **Director:** "Final RPN: [10, 5, +, 2, *, 3, -]. Compare this to the original—TOTALLY different order! It's like we shuffled a deck and actually got a better hand. That's the algorithm WINNING."
//
// ---
//
// ### Calculate
//
// **Calculator:** "10... 5... both on the stack."
// *[they sit]*
//
// **Calculator:** "Plus sign! Pop twice. 10 + 5 equals?"
// **Everyone:** "15!" *[Token-2 changes to 15, or a Token changes]*
//
// *[Token changes to 15]*
//
// **Calculator:** "Stack the 2. Multiply! Pop twice. 15 * 2 equals?"
// **Everyone:** "30!" *[Token changes to 30]*
//
// **Calculator:** "Stack the 3. Minus! Pop twice. 30 - 3 equals?"
// **Everyone:** "27!"
//
// **Director:** "27! TWENTY-SEVEN! Without those parentheses, we would've gotten a TOTALLY different answer. Try it at home! (10 + 5) * 2 - 3 is NOT the same as 10 + 5 * 2 - 3. Your calculator WILL NOT lie to you, but ORDER OF OPERATIONS WILL."
//
// **Data Explainer 1:** "HashMap stored the operators. ArrayList kept order. Stack handled the tricky precedence and grouping. Three structures. One PERFECT ANSWER."
//
// **Director:** "And THAT'S why your math teachers are so annoying about parentheses. They're literally THE LAW."

// %% [markdown]
// ## SCRIPT: Hard Version `√(3^2 + 4^2)` - Pythagorean Theorem
//
// **Director:** "Final round—the PYTHAGOREAN THEOREM. Holy moly. √(3^2 + 4^2). This has EVERYTHING: square root, exponents, parentheses, addition. At this point, the algorithm is basically running a small government."
//
// **Data Explainer 2:** "Watch how precedence works here. Square root is 1, exponent is 2, addition is 4. Lower number goes first. The square root is the MOST IMPORTANT. It's running this whole operation like a CEO."
//
// ### Tokenize It
//
// **Tokenizer:** "Square root!" *[Token-√ walks forward with an air of superiority, clearly the main character]*
// **Tokenizer:** "Open paren!" *[Token-( walks forward, subordinate to the square root, knows its place]*
// **Tokenizer:** "3!" *[Token-3 walks forward]*
// **Tokenizer:** "Exponent!" *[Token-^ walks forward looking ambitious]*
// **Tokenizer:** "2!" *[Token-2 walks forward]*
// **Tokenizer:** "Plus!" *[Token-+ walks forward, shell-shocked from last round]*
// **Tokenizer:** "4!" *[Token-4 walks forward, looking confident]*
// **Tokenizer:** "Exponent again!" *[Token-^ returns, now feeling special because it appears twice]*
// **Tokenizer:** "And 2!" *[Token-2 returns, confused about why it's back]*
// **Tokenizer:** "Close paren!" *[Token-) walks forward, salutes the square root, clearly the second in command]*
//
// **Director:** "Ten tokens total! [√, (, 3, ^, 2, +, 4, ^, 2, )]. And if you count them, there are TEN. MATH CHECKS OUT."
//
// ---
//
// ### RPN Time (This Gets Intense!)
//
// **RPN Boss:** "Square root, onto the stack!" *[√ sits on the highest, most important chair—literally a throne if possible]*
//
// **RPN Boss:** "Open paren, stack it!"
// *[( sits on a regular chair, below the√]*
//
// **RPN Boss:** "3, you're a number. RPN output!"
// *[3 moves to RPN area]*
//
// **RPN Boss:** "First exponent—precedence 2. Stack is just paren so get on!" *[^ sits on chair, very proud]*
//
// **RPN Boss:** "2, to RPN!"
// *[2 moves]*
//
// **RPN Boss:** "Plus sign—precedence 4. But exponent is precedence 2. Lower wins!"
//
// **Director:** "See that? The exponent FORCES OUT before plus can go on the stack! The exponent is like 'NOT TODAY, PLUS.'"
//
// **RPN Boss:** *[^ gets violently launched into RPN]* "Now plus, get on the stack."
// *[+ sits down, still processing the trauma from the previous round]*
//
// **RPN Boss:** "4, RPN!"
// *[4 moves]*
//
// **RPN Boss:** "Second exponent. Plus is precedence 4, I'm precedence 2. I WIN!"
// *[+ gets brutally ejected, ^ gets back on the chair looking smug]*
// "Now I'm on."
//
// **RPN Boss:** "Last 2, RPN!"
// *[2 moves, wondering if this will ever end]*
//
// **RPN Boss:** "Close paren—dump EVERYTHING to the open paren!"
// *[^ gets yeeted to RPN, + gets yeeted to RPN, ( disappears forever]*
//
// **Director:** "Parentheses gone. But the square root? STILL ON THE THRONE. Still waiting. Patience is the square root's greatest virtue."
//
// **RPN Boss:** "No more tokens. Clear the stack!"
// *[√ descends from the throne in slow motion, walks majestically to RPN]*
//
// **Director:** "RPN complete: [3, 2, ^, 4, 2, ^, +, √]. That square root is LAST even though it was FIRST in the original! It's been waiting this whole time like a boss waiting for their coffee order."
//
// ---
//
// ### Calculate (The Magic Moment)
//
// **Calculator:** "3 on the stack. 2 on the stack."
// *[they sit, prepare]*
//
// **Calculator:** "Exponent! Pop twice. 3 to the power of 2?"
// **Everyone:** "9!" *[Token-2 changes phone to 9, sits back down like it won a battle]*
//
// **Calculator:** "Stack the 4. Stack the next 2."
// *[they sit down]*
//
// **Calculator:** "Exponent AGAIN! Pop twice. 4 squared?"
// **Everyone:** "16!" *[Token-2 changes to 16, the audience is getting into it]*
//
// **Calculator:** "Now we've got 9 and 16 on the stack. Plus sign! Pop both. 9 + 16?"
// **Everyone:** "25!" *[Token-2 changes to 25, everyone gasps—it's a PERFECT SQUARE]*
//
// **Director:** "And NOW for the FINALE... the moment we've been WAITING for..."
//
// **Calculator:** "Square root! This is a unary operator—only ONE operand. Pop once. Square root of 25?"
// **Everyone:** "FIVE!" *[Token-2 shows 5, all cast members LOSE THEIR MINDS]*
//
// **Director:** "FIIIIIVE! THE PYTHAGOREAN THEOREM! A 3-4-5 right triangle! The computer just PROVED GEOMETRY! With DANCING!"
//
// *[All cast members take a bow. Token-√ takes multiple bows. It knew it would be victorious.]*
//
// **Data Explainer 1:** "Notice how the square root waited until the VERY END? That's because the parentheses forced everything inside to calculate FIRST. Stack power! It's like the square root was a chess grandmaster waiting for its moment."
//
// **Data Explainer 2:** "And the HashMap knew square root only takes ONE argument, not two. So we only popped ONCE. Precision. Efficiency. Respect the HashMap."
//
// **Director:** "And THAT, class, is why computers are better at math than us. They don't get emotional. They just DO THE THING. Now everyone take your seat before I make you compute something harder."

// %% [markdown]
// ## Quick Tips
//
// **Before You Perform:**
// - Download a big number app on your phone (search "LED display" or "big text")
// - Practice switching values fast (3 → 6 → 11)
// - Run through it twice - once slow, once at performance speed
// - Use tape on the floor to mark where tokens stand
//
// **During the Performance:**
// - SPEAK LOUD - the class needs to hear you
// - Move between stations - don't just stand there
// - Make eye contact when "calculating" with another token
// - ham it up when parentheses "disappear" or when two tokens "compress"
//
// **Common Mistakes:**
// - Mixing up pop order (first pop = second operand!)
// - Forgetting precedence (lower number = higher priority)
// - Rushing - slow down, let people understand
//
// **The Point:**
// You're not just acting.  You're showing how THREE data structures (HashMap, ArrayList, Stack) work together to solve one problem. Make that clear!

// %% [markdown]
// ## Data Structures - What You're Actually Showing
//
// **HashMap** (in the operators)
// - Like a cheat sheet - instant lookup of operator precedence
// - O(1) speed - super fast
// - In your enactment: The RPN Boss has a reference card
//
// **ArrayList** (the token lists and RPN output)
// - Keeps things in order
// - Like a line at lunch - first in stays first
// - In your enactment: Tokens line up horizontally
//
// **Stack** (operator stack + calculation stack)
// - Last in, first out (LIFO)
// - Like a stack of plates - only touch the top one
// - In your enactment: Tokens stand vertically, only the front person can leave
// - THIS is how we handle precedence and calculations!
//
// **The Combo:**
// All three work together. HashMap tells us rules. ArrayList keeps order. Stack makes it actually compute correctly.

// %% [markdown]
// ## Testing the Code
//
// Run the calculator with your enactment expressions to verify the results:

// %%
import java.util.function.BiFunction;

/**
 * Token class represents fundamental components of a mathematical expression
 */
public class Token {
    private final Character token;
    private final int precedence;
    private final BiFunction<Double, Double, Double> calculation;
    private final int numArgs;

    public Token() {
        this('0');
    }

    public Token(Character token) {
        this(token, 0, null, 0);
    }

    public Token(Character token, int precedence, BiFunction<Double, Double, Double> calculation, int numArgs) {
        this.token = token;
        this.precedence = precedence;
        this.calculation = calculation;
        this.numArgs = numArgs;
    }

    public Character getToken() {
        return token;
    }

    public int getPrecedence() {
        return precedence;
    }

    public int getNumArgs() {
        return numArgs;
    }

    public boolean isPrecedent(Token token) {
        return this.precedence > token.getPrecedence();
    }

    public Double calculate(Double operand1, Double operand2) {
        return this.calculation.apply(operand1, operand2);
    }

    public String toString() {
        return this.token.toString();
    }
}

// %%
import java.util.function.BiFunction;

/**
 * TermOrOperator class extends Token
 * Represents either a value, operator, or parenthesis
 */
public class TermOrOperator extends Token {
    private final String value;

    // Constructor for values
    public TermOrOperator(String value) {
        this.value = value;
    }

    // Constructor for parenthesis
    public TermOrOperator(Character token) {
        super(token);
        this.value = null;
    }

    // Constructor for operators
    public TermOrOperator(Character token, int precedence, BiFunction<Double, Double, Double> calculation) {
        super(token, precedence, calculation, 2);
        this.value = null;
    }

    // Constructor for operators with custom arg count
    public TermOrOperator(Character token, int precedence, BiFunction<Double, Double, Double> calculation, int numArgs) {
        super(token, precedence, calculation, numArgs);
        this.value = null;
    }

    public String getValue() {
        return value;
    }

    public String toString() {
        if (this.value == null) {
            return super.toString();
        }
        return this.value;
    }
}

// %%
import java.util.Map;
import java.util.function.BiFunction;
import java.util.HashMap;

/**
 * Tokens class manages a collection of operators and separators
 * Uses HashMap for O(1) lookup performance
 */
public class Tokens {
    private Map<Character, TermOrOperator> map;

    public Tokens() {
        this.map = new HashMap<>();
    }

    // Put method for parenthesis and separators
    public void put(Character token) {
        this.map.put(token, new TermOrOperator(token));
    }

    // Put method for operators with custom arg count
    public void put(Character token, int precedence, BiFunction<Double, Double, Double> calculation, int numArgs) {
        this.map.put(token, new TermOrOperator(token, precedence, calculation, numArgs));
    }

    // Put method for binary operators
    public void put(Character token, int precedence, BiFunction<Double, Double, Double> calculation) {
        this.map.put(token, new TermOrOperator(token, precedence, calculation));
    }

    public TermOrOperator get(Character token) {
        return this.map.get(token);
    }

    public int getPrecedence(Character token) {
        return this.map.get(token).getPrecedence();
    }

    public boolean contains(Character token) {
        return this.map.containsKey(token);
    }

    public String toString() {
        return this.map.toString();
    }
}

// %%
import java.util.ArrayList;
import java.util.Stack;

/**
 * Calculator class - converts mathematical expressions to RPN and calculates result
 * This is the main class that demonstrates the algorithm you'll enact
 */
public class Calculator {
    private final String expression;
    private ArrayList<TermOrOperator> terms = new ArrayList<>();
    private ArrayList<TermOrOperator> rpnTerms = new ArrayList<>();
    private Tokens operators = new Tokens();
    private Tokens seperators = new Tokens();
    private Double result = 0.0;

    public Calculator(String expression) {
        initOperators();
        initSeperators();
        this.expression = expression;
        this.termTokenizer();
        this.termsToRPN();
        this.rpnToResult();
    }

    /**
     * Initialize operators with precedence and calculation
     * Lower precedence number = higher priority
     */
    private void initOperators() {
        operators.put('^', 2, (a, b) -> Math.pow(a, b));
        operators.put('*', 3, (a, b) -> a * b);
        operators.put('/', 3, (a, b) -> a / b);
        operators.put('%', 3, (a, b) -> a % b);
        operators.put('+', 4, (a, b) -> a + b);
        operators.put('-', 4, (a, b) -> a - b);
        operators.put('√', 1, (a, b) -> Math.sqrt(a), 1);
    }

    private void initSeperators() {
        seperators.put(' ');
        seperators.put('(');
        seperators.put(')');
    }

    /**
     * PHASE 1: Tokenization
     * Breaks expression into individual terms/operators
     */
    private void termTokenizer() {
        int start = 0;
        StringBuilder multiCharTerm = new StringBuilder();
        for (int i = 0; i < this.expression.length(); i++) {
            Character c = this.expression.charAt(i);

            if (operators.contains(c) || seperators.contains(c)) {
                if (multiCharTerm.length() > 0) {
                    this.terms.add(new TermOrOperator(this.expression.substring(start, i)));
                }
                TermOrOperator t = operators.get(c);
                if (t == null) {
                    t = seperators.get(c);
                }
                if (t != null && t.getToken() != ' ') {
                    this.terms.add(t);
                }
                start = i + 1;
                multiCharTerm = new StringBuilder();
            } else {
                multiCharTerm.append(c);
            }
        }
        if (multiCharTerm.length() > 0) {
            this.terms.add(new TermOrOperator(this.expression.substring(start)));
        }
    }

    /**
     * PHASE 2: Convert to RPN using Shunting-Yard algorithm
     * This is the complex part you'll enact with the operator stack!
     */
    private void termsToRPN() {
        Stack<TermOrOperator> operatorStack = new Stack<>();

        for (TermOrOperator term : terms) {
            if (term.getToken() == '(') {
                operatorStack.push(term);
            } else if (term.getToken() == ')') {
                while (operatorStack.peek() != null && operatorStack.peek().getToken() != '(') {
                    rpnTerms.add(operatorStack.pop());
                }
                operatorStack.pop(); // remove '('
            } else if (operators.contains(term.getToken())) {
                while (!operatorStack.isEmpty() && 
                       operators.contains(operatorStack.peek().getToken()) && 
                       term.isPrecedent(operatorStack.peek())) {
                    rpnTerms.add(operatorStack.pop());
                }
                operatorStack.push(term);
            } else {
                this.rpnTerms.add(term);
            }
        }
        while (!operatorStack.isEmpty()) {
            rpnTerms.add(operatorStack.pop());
        }
    }

    /**
     * PHASE 3: Calculate result from RPN
     * This is where the calculation stack comes in!
     */
    private void rpnToResult() {
        Stack<Double> calcStack = new Stack<Double>();

        for (TermOrOperator term : this.rpnTerms) {
            Double operand1 = 0.0, operand2 = 0.0, result = 0.0;

            if (operators.contains(term.getToken())) {
                if (term.getNumArgs() == 1) {
                    operand1 = calcStack.pop();
                } else {
                    operand2 = calcStack.pop();
                    operand1 = calcStack.pop();
                }
                result = term.calculate(operand1, operand2);
                calcStack.push(result);
            } else {
                calcStack.push(Double.valueOf(term.getValue()));
            }
        }
        this.result = calcStack.pop();
    }

    public String toString() {
        return ("Original expression: " + this.expression + "\n" +
                "Tokenized expression: " + this.terms.toString() + "\n" +
                "Reverse Polish Notation: " + this.rpnTerms.toString() + "\n" +
                "Final result: " + String.format("%.2f", this.result));
    }
}

// %%
/**
 * Main class to test the Calculator with enactment examples
 */
public class CalculatorTester {
    public static void main(String[] args) {
        System.out.println("=== SIMPLE EXAMPLE ===");
        Calculator simple = new Calculator("5 + 3 * 2");
        System.out.println(simple);
        System.out.println();

        System.out.println("=== INTERESTING EXAMPLE (with parentheses) ===");
        Calculator interesting = new Calculator("(10 + 5) * 2 - 3");
        System.out.println(interesting);
        System.out.println();

        System.out.println("=== ADVANCED EXAMPLE (Pythagorean Theorem) ===");
        Calculator advanced = new Calculator("√(3^2 + 4^2)");
        System.out.println(advanced);
        System.out.println();

        System.out.println("=== BONUS: Complex Expression ===");
        Calculator bonus = new Calculator("100 + 200 * 3");
        System.out.println(bonus);
    }
}

CalculatorTester.main(null);
// Out:
// === SIMPLE EXAMPLE ===
// Original expression: 5 + 3 * 2
// Tokenized expression: [5, +, 3, *, 2]
// Reverse Polish Notation: [5, 3, 2, *, +]
// Final result: 11.00
//
// === INTERESTING EXAMPLE (with parentheses) ===
// Original expression: (10 + 5) * 2 - 3
// Tokenized expression: [(, 10, +, 5, ), *, 2, -, 3]
// Reverse Polish Notation: [10, 5, +, 2, *, 3, -]
// Final result: 27.00
//
// === ADVANCED EXAMPLE (Pythagorean Theorem) ===
// Original expression: √(3^2 + 4^2)
// Tokenized expression: [√, (, 3, ^, 2, +, 4, ^, 2, )]
// Reverse Polish Notation: [3, 2, ^, 4, 2, ^, +, √]
// Final result: 5.00
//
// === BONUS: Complex Expression ===
// Original expression: 100 + 200 * 3
// Tokenized expression: [100, +, 200, *, 3]
// Reverse Polish Notation: [100, 200, 3, *, +]
// Final result: 700.00

// %% [markdown]
// ## Your Blog Write-Up
//
// **What to Include:**
// 1. Team members and who did what
// 2. Which expressions you used and why
// 3. Photos or video of the performance
// 4. Explain the three data structures (HashMap, ArrayList, Stack) and where each was used
// 5. What went wrong and how you fixed it
//
// **Questions to Answer:**
// - Why is RPN easier for computers than regular math notation?
// - How does Stack help with operator precedence?
// - Why HashMap instead of a bunch of if statements?
// - Where else would you use stacks in programming?
//
// **Grading:**
// - Can people understand what's happening? (40%)
// - Did you get the algorithm right? (30%)
// - Did your team work smoothly? (15%)
// - Is your blog complete? (15%)

// %% [markdown]
// ## Cheat Sheet
//
// **Precedence (lower number = do it first):**
// - √ = 1
// - ^ = 2
// - *, /, % = 3
// - +, - = 4
//
// **The Algorithm:**
// 1. **Tokenize:** Break expression into pieces
// 2. **RPN:** Numbers go straight through. Operators wait on stack based on precedence. Parentheses control when things pop.
// 3. **Calculate:** Stack numbers. When you hit an operator, pop two, calculate, push result back.
//
// **Remember:**
// - First pop = second operand (order matters!)
// - Parentheses don't make it to RPN (they just control the stack)
// - Lower precedencenumber means do it first
